# %% [markdown]
# # Preparing datasets

# %% [markdown]
# Let's get started by loading two datasets:

# %%
import pandas as pd
import numpy as np

dataset_1 = pd.read_csv('DM_1.csv', encoding='latin1')
dataset_2 = pd.read_csv('DM_2.csv', encoding='latin1')

# %%
dataset_1
# Out:
#                Name                                    Email            City  \
# 0     Brent Hopkins       Cum.sociis.natoque@aodiosemper.edu     Mount Pearl
# 1       Colt Bender              Vivamus.non.lorem@Proin.org  Castle Douglas
# 2    Arthur Hammond                    nisl.Maecenas@sed.net          Biloxi
# 3       Sean Warner          enim.nisl.elementum@Vivamus.edu           Moere
# 4       Tate Greene  velit.justo.nec@aliquetlobortisnisi.edu         Ipswich
# 5      Gavin Gibson    cursus.Integer.mollis@Duissitamet.org        Oordegem
# 6       Kelly Garza       cursus.non.egestas@antebibendum.ca      Kukatpalle
# 7      Zane Preston                 sed@Phasellusataugue.com        Neudrfl
# 8   Cole Cunningham           ac.mattis.ornare@inmagna.co.uk          Catemu
# 9   Tarik Hendricks             Mauris.vestibulum@sodales.ca         Newbury
# 10    Elvis Collier                     pede@mattisvelit.org        Paradise
# 11    Jackson Huber      eros.nec.tellus@ultricesposuere.edu           Veere
# 12   Macaulay Cline                    Aliquam@arcuSedeu.edu      Campobasso
# 13     Elijah Chase                    est.mollis.non@in.net        Grantham
# 14   Dennis Anthony              mauris.ut.mi@maurisid.co.uk    Cedar Rapids
# 15    Fulton Snyder                       enim.mi@egestas.ca       San Pedro
# 16       Leo Willis          massa.lobortis@mattisornare.edu          Kester
# 17   Matthew Hooper               libero@Nuncullamcorper.net   Bellefontaine
# 18       Todd Jones              ipsum.Phasellus@ultrices.ca          Toledo
# 19      Palmer Byrd                faucibus.orci@necquam.org        Bissegem
#
#     Salary
# 0    38363
# 1    21506
# 2    27511
# 3    25201
# 4    35052
# 5    37126
# 6    39420
# 7    28553
# 8    27972
# 9    39027
# 10   22568
# 11   29922
# 12   24163
# 13   23881
# 14   27969
# 15   21594
# 16   31203
# 17   33222
# 18   24809
# 19   29045

# %%
dataset_2
# Out:
#         Colt       BENDER  252
# 0     Arthur      HAMMOND  138
# 1      Gavin       GIBSON  146
# 2      Kelly        GARZA  212
# 3       Zane      PRESTON  234
# 4       Zane      PRESTON  178
# 5      Tarik    HENDRICKS  195
# 6      Elvis      COLLIER   95
# 7      Elvis      COLLIER  101
# 8      Elvis      COLLIER  258
# 9     Dennis      ANTHONY  254
# 10    Fulton       SNYDER  107
# 11       Leo       WILLIS  294
# 12  Frederik  HUMBLEDERRY  299

# %% [markdown]
# As you can see, the second dataset does not have column headers. We can add them as follows:

# %%
cols = ['First name', 'Last name', 'Days active']
dataset_2 = pd.read_csv('DM_2.csv', names=cols, encoding='latin1')
dataset_2
# Out:
#    First name    Last name  Days active
# 0        Colt       BENDER          252
# 1      Arthur      HAMMOND          138
# 2       Gavin       GIBSON          146
# 3       Kelly        GARZA          212
# 4        Zane      PRESTON          234
# 5        Zane      PRESTON          178
# 6       Tarik    HENDRICKS          195
# 7       Elvis      COLLIER           95
# 8       Elvis      COLLIER          101
# 9       Elvis      COLLIER          258
# 10     Dennis      ANTHONY          254
# 11     Fulton       SNYDER          107
# 12        Leo       WILLIS          294
# 13   Frederik  HUMBLEDERRY          299

# %% [markdown]
# We can convert the second dataset to only have one column for names:

# %%
# .title() can be used to only make the first letter a capital
names = [dataset_2.loc[i,'First name'] + " " + dataset_2.loc[i,'Last name'].title() for i in range(0, len(dataset_2))]

# Make a new column for the name
dataset_2['Name'] = names

# Remove the old columns
dataset_2 = dataset_2.drop(['First name', 'Last name'], axis=1)
dataset_2
# Out:
#     Days active                  Name
# 0           252           Colt Bender
# 1           138        Arthur Hammond
# 2           146          Gavin Gibson
# 3           212           Kelly Garza
# 4           234          Zane Preston
# 5           178          Zane Preston
# 6           195       Tarik Hendricks
# 7            95         Elvis Collier
# 8           101         Elvis Collier
# 9           258         Elvis Collier
# 10          254        Dennis Anthony
# 11          107         Fulton Snyder
# 12          294            Leo Willis
# 13          299  Frederik Humblederry

# %% [markdown]
# ## Bringing together the datasets

# %% [markdown]
# Now the datasets are compatible, we can merge them in a few different ways.

# %% [markdown]
# ### Left join

# %% [markdown]
# A left join starts from the left dataset, in this case ```dataset_1```, and for every row matches the value in the column used for joining. As you will see, the result has 22 rows, since some names appear multiple times in the second dataset ```dataset_2```.

# %%
both = pd.merge(dataset_1, dataset_2, on='Name', how='left')
both
# Out:
#                Name                                    Email            City  \
# 0     Brent Hopkins       Cum.sociis.natoque@aodiosemper.edu     Mount Pearl
# 1       Colt Bender              Vivamus.non.lorem@Proin.org  Castle Douglas
# 2    Arthur Hammond                    nisl.Maecenas@sed.net          Biloxi
# 3       Sean Warner          enim.nisl.elementum@Vivamus.edu           Moere
# 4       Tate Greene  velit.justo.nec@aliquetlobortisnisi.edu         Ipswich
# 5      Gavin Gibson    cursus.Integer.mollis@Duissitamet.org        Oordegem
# 6       Kelly Garza       cursus.non.egestas@antebibendum.ca      Kukatpalle
# 7      Zane Preston                 sed@Phasellusataugue.com        Neudrfl
# 8      Zane Preston                 sed@Phasellusataugue.com        Neudrfl
# 9   Cole Cunningham           ac.mattis.ornare@inmagna.co.uk          Catemu
# 10  Tarik Hendricks             Mauris.vestibulum@sodales.ca         Newbury
# 11    Elvis Collier                     pede@mattisvelit.org        Paradise
# 12    Elvis Collier                     pede@mattisvelit.org        Paradise
# 13    Elvis Collier                     pede@mattisvelit.org        Paradise
# 14    Jackson Huber      eros.nec.tellus@ultricesposuere.edu           Veere
# 15   Macaulay Cline                    Aliquam@arcuSedeu.edu      Campobasso
# 16     Elijah Chase                    est.mollis.non@in.net        Grantham
# 17   Dennis Anthony              mauris.ut.mi@maurisid.co.uk    Cedar Rapids
# 18    Fulton Snyder                       enim.mi@egestas.ca       San Pedro
# 19       Leo Willis          massa.lobortis@mattisornare.edu          Kester
# 20   Matthew Hooper               libero@Nuncullamcorper.net   Bellefontaine
# 21       Todd Jones              ipsum.Phasellus@ultrices.ca          Toledo
# 22      Palmer Byrd                faucibus.orci@necquam.org        Bissegem
#
#     Salary  Days active
# 0    38363          NaN
# 1    21506        252.0
# 2    27511        138.0
# 3    25201          NaN
# 4    35052          NaN
# 5    37126        146.0
# 6    39420        212.0
# 7    28553        234.0
# 8    28553        178.0
# 9    27972          NaN
# 10   39027        195.0
# 11   22568         95.0
# 12   22568        101.0
# 13   22568        258.0
# 14   29922          NaN
# 15   24163          NaN
# 16   23881          NaN
# 17   27969        254.0
# 18   21594        107.0
# 19   31203        294.0
# 20   33222          NaN
# 21   24809          NaN
# 22   29045          NaN

# %% [markdown]
# ### Right join

# %% [markdown]
# A right join does the opposite: now, ```dataset_2``` is used to match all names with the corresponding observations in ```dataset_1```. There are as many observations as there are in ```dataset_2```, as the rows in ```dataset_1``` are unique. The last row cannot be matched with any observation in ```dataset_1```.

# %%
both = pd.merge(dataset_1, dataset_2, on='Name', how='right')
both
# Out:
#                     Name                                  Email  \
# 0            Colt Bender            Vivamus.non.lorem@Proin.org
# 1         Arthur Hammond                  nisl.Maecenas@sed.net
# 2           Gavin Gibson  cursus.Integer.mollis@Duissitamet.org
# 3            Kelly Garza     cursus.non.egestas@antebibendum.ca
# 4           Zane Preston               sed@Phasellusataugue.com
# 5           Zane Preston               sed@Phasellusataugue.com
# 6        Tarik Hendricks           Mauris.vestibulum@sodales.ca
# 7          Elvis Collier                   pede@mattisvelit.org
# 8          Elvis Collier                   pede@mattisvelit.org
# 9          Elvis Collier                   pede@mattisvelit.org
# 10        Dennis Anthony            mauris.ut.mi@maurisid.co.uk
# 11         Fulton Snyder                     enim.mi@egestas.ca
# 12            Leo Willis        massa.lobortis@mattisornare.edu
# 13  Frederik Humblederry                                    NaN
#
#               City   Salary  Days active
# 0   Castle Douglas  21506.0          252
# 1           Biloxi  27511.0          138
# 2         Oordegem  37126.0          146
# 3       Kukatpalle  39420.0          212
# 4         Neudrfl  28553.0          234
# 5         Neudrfl  28553.0          178
# 6          Newbury  39027.0          195
# 7         Paradise  22568.0           95
# 8         Paradise  22568.0          101
# 9         Paradise  22568.0          258
# 10    Cedar Rapids  27969.0          254
# 11       San Pedro  21594.0          107
# 12          Kester  31203.0          294
# 13             NaN      NaN          299

# %% [markdown]
# ### Inner and outer join

# %% [markdown]
# It is also possible to retain only the values that are matched in both tables, or match any value that matches. This is using an inner and outer join respectively.

# %%
both = pd.merge(dataset_1, dataset_2, on='Name', how='inner')
both
# Out:
#                Name                                  Email            City  \
# 0       Colt Bender            Vivamus.non.lorem@Proin.org  Castle Douglas
# 1    Arthur Hammond                  nisl.Maecenas@sed.net          Biloxi
# 2      Gavin Gibson  cursus.Integer.mollis@Duissitamet.org        Oordegem
# 3       Kelly Garza     cursus.non.egestas@antebibendum.ca      Kukatpalle
# 4      Zane Preston               sed@Phasellusataugue.com        Neudrfl
# 5      Zane Preston               sed@Phasellusataugue.com        Neudrfl
# 6   Tarik Hendricks           Mauris.vestibulum@sodales.ca         Newbury
# 7     Elvis Collier                   pede@mattisvelit.org        Paradise
# 8     Elvis Collier                   pede@mattisvelit.org        Paradise
# 9     Elvis Collier                   pede@mattisvelit.org        Paradise
# 10   Dennis Anthony            mauris.ut.mi@maurisid.co.uk    Cedar Rapids
# 11    Fulton Snyder                     enim.mi@egestas.ca       San Pedro
# 12       Leo Willis        massa.lobortis@mattisornare.edu          Kester
#
#     Salary  Days active
# 0    21506          252
# 1    27511          138
# 2    37126          146
# 3    39420          212
# 4    28553          234
# 5    28553          178
# 6    39027          195
# 7    22568           95
# 8    22568          101
# 9    22568          258
# 10   27969          254
# 11   21594          107
# 12   31203          294

# %% [markdown]
# Notice how observation 12 is missing, as there is no corresponding value in ```dataset_1```.

# %%
both = pd.merge(dataset_1, dataset_2, on='Name', how='outer')
both
# Out:
#                     Name                                    Email  \
# 0          Brent Hopkins       Cum.sociis.natoque@aodiosemper.edu
# 1            Colt Bender              Vivamus.non.lorem@Proin.org
# 2         Arthur Hammond                    nisl.Maecenas@sed.net
# 3            Sean Warner          enim.nisl.elementum@Vivamus.edu
# 4            Tate Greene  velit.justo.nec@aliquetlobortisnisi.edu
# 5           Gavin Gibson    cursus.Integer.mollis@Duissitamet.org
# 6            Kelly Garza       cursus.non.egestas@antebibendum.ca
# 7           Zane Preston                 sed@Phasellusataugue.com
# 8           Zane Preston                 sed@Phasellusataugue.com
# 9        Cole Cunningham           ac.mattis.ornare@inmagna.co.uk
# 10       Tarik Hendricks             Mauris.vestibulum@sodales.ca
# 11         Elvis Collier                     pede@mattisvelit.org
# 12         Elvis Collier                     pede@mattisvelit.org
# 13         Elvis Collier                     pede@mattisvelit.org
# 14         Jackson Huber      eros.nec.tellus@ultricesposuere.edu
# 15        Macaulay Cline                    Aliquam@arcuSedeu.edu
# 16          Elijah Chase                    est.mollis.non@in.net
# 17        Dennis Anthony              mauris.ut.mi@maurisid.co.uk
# 18         Fulton Snyder                       enim.mi@egestas.ca
# 19            Leo Willis          massa.lobortis@mattisornare.edu
# 20        Matthew Hooper               libero@Nuncullamcorper.net
# 21            Todd Jones              ipsum.Phasellus@ultrices.ca
# 22           Palmer Byrd                faucibus.orci@necquam.org
# 23  Frederik Humblederry                                      NaN
#
#               City   Salary  Days active
# 0      Mount Pearl  38363.0          NaN
# 1   Castle Douglas  21506.0        252.0
# 2           Biloxi  27511.0        138.0
# 3            Moere  25201.0          NaN
# 4          Ipswich  35052.0          NaN
# 5         Oordegem  37126.0        146.0
# 6       Kukatpalle  39420.0        212.0
# 7         Neudrfl  28553.0        234.0
# 8         Neudrfl  28553.0        178.0
# 9           Catemu  27972.0          NaN
# 10         Newbury  39027.0        195.0
# 11        Paradise  22568.0         95.0
# 12        Paradise  22568.0        101.0
# 13        Paradise  22568.0        258.0
# 14           Veere  29922.0          NaN
# 15      Campobasso  24163.0          NaN
# 16        Grantham  23881.0          NaN
# 17    Cedar Rapids  27969.0        254.0
# 18       San Pedro  21594.0        107.0
# 19          Kester  31203.0        294.0
# 20   Bellefontaine  33222.0          NaN
# 21          Toledo  24809.0          NaN
# 22        Bissegem  29045.0          NaN
# 23             NaN      NaN        299.0

# %% [markdown]
# In the last table, we have 23 rows, as both matching and non-matching values are returned.

# %% [markdown]
# Now that you have seen one way to merge datasets, spend some time experimenting to discover other quicker, easier or preferable ways to achieve the same result.
